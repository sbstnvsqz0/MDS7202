# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2024</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Sebastián Tinoco
# - Auxiliar: Catherine Benavides
# - Ayudante: Nicolás Ojeda, Eduardo Moya

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Sebastián Vásquez S.
# - Nombre de alumno 2:

# %% [markdown]
# ### **Link de repositorio de GitHub: https://github.com/sbstnvsqz0/MDS7202**

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 7 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos Y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquer material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# 1. Git es un sistema de control de versiones distribuido, es decir, la copia del trabajo de cada persona es un repositorio que alberga el historial completo de cambios.
# 2. A continuación se enumeran 3 diferencias entre Git y Github:
# - Git es un sistema de control de versiones distribuido, mientras que github es un servicio de alojamiento basado en web donde se pueden guardar versiones de repositorios controlados por git.
# - Git es una herramienta de línea de comando, mientras que github da simplemente una interfaz gráfica; es decir, git muestra líneas de comandos, mientras que github muestra los resultados de los comandos.
# - Git puede crear repositorios de forma local para trackear cambios locales, mientras que Github es un espacio web para subir copias de repositorios monitoreados por Git; es decir, uno trabaja de forma local, mientras que el otro trabaja en la web.
# 3. Los hash son los ids únicos de cada commit, blob o árbol. Un ejemplo de como se ven los hash, es al hacer git log en la carpeta de la lab1 de la P3, se puede ver el primer commit con un hash de la forma b262d86411a6b017e99bf0731e33a6787739247c.
# 4. Los elementos son:
# - Los árboles, los cuales representan los directorios (pueden contener blobs y árboles).
# - Los blobs, donde se almacena el contenido de los archivos.
# - Los commits, los cuales son las capturas que registran y consolidan los cambios.
# 5. Para crear un repositorio se debe estar de forma local en el directorio en cuestión y hacer git init. Luego para hacer seguimiento de los archivos dentro del repositorio, se debe hacer un git add [nombre de archivo a hacer seguimiento].

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. F. Hay veces donde se hacen cambios sobre un mismo archivo en dos diferentes ramas lo cual provoca colisiones al hacer el merge, lo cual no se soluciona de forma automática.
# 7. F. git clone se encarga de obtener todo el repositorio en cuestión, mientras que git pull, al estar sobre un repositorio ya clonado, solo se encarga de obtener los cambios o actualizaciones hechas al repositorio.
# 8. F. git status permite ver los archivos sobre los cuales se han hecho cambios, dando información de los que no se han commiteado o agregado al repositorio, en cambio git log muestra el historial de los commits con información detallada al respecto.
# 9. V. Usando comandos relativos a git checkout. Por ejemplo: git checkout -- folder/file para revertir cambios al commit anterior de un archivo (file) en específico, o git checkout commit-hash para poder retornar todos los atchivos a un commit anterior.
# 10. F. Para enviar cambios al repositorio remoto se utiliza el git push. git commit, crea la captura del directorio de forma local.

# %% [markdown]
# Por último, investigue y comente para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# 11. git stash almacena temporalmente los cambios en lo que se este trabajando en stashes. En este caso se toman los cambios sin confirmar y los guarda aparte para poder usarlos más adelante. Para volver a ver los cambios del stash se debe usar git stash pop.
# 12. git reset restablece el estado actual a un estado en específico, eliminando los commits intermedios, en cambio, git revert deshace cambios realizados por commits anteriores, creando un commit nuevo, dando pie a tener un historial más limpio de commits.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code>
# https://github.com/sbstnvsqz0
#
# <code>Link Presentacion 2:</code>

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Para clonar primero se utilizó git init en la carpeta donde se va a clonar y luego, estando en el directorio, git clone https://github.com/MDS7202/lab1.git
# ```
# git init
# git clone https://github.com/MDS7202/lab1.git
# ```

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# El objetivo del proyecto es lograr un ejecutable el cual, al ingresar un animal, se pueda conocer el sonido que este emite.
# El repositorio se compone de 3 files:
# - animales.py: es un script donde se define la función para conseguir los sonidos de los animales. Solo está especificado para las entradas gato, perro y fox.
# - main: es el script ejecutable del proyecto.
# - readme: es un .md que explica el objetivo del proyecto: emular los sonidos de los animales.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# A continuación se describe el proceso del proyecto según los commits:
# 1. Se hace el primer commit de nombre primer commit (no es del todo explicativo)
# 2. El segundo commit tiene de comentario 'se agrega funcion', lo cual se creería que se refiere a la función animales (tampoco es del todo claro)
# 3. Ahora se agregó una rama El tercer commit dice que se separa el proyecto en módulos, donde se pueden ver las ramas origin/new_features, origin/main y origin/HEAD, las cuales son ramas remotas asociadas a este commit.
# 4. Finalmente, el 4to commit reconocido es el de fix ifs, el cual está en la rama origin/fix-ifs y que se trabajó desde el 2do commit.
# En conclusión, los commits no son del todo explicativos, pues los primeros en especial no describen de manera entendible lo que se hizo.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# En este caso, al ejecutar el .py y dar de input perro o gato, da el sonido esperado, sin embargo, se agrega el error de animal no reconocido, lo cual no tiene sentido. El error recae en el no uso de elif, pues va revisando if por if hasta llegar al else y si la condición del if final es falso, entonces el código va a tomar el else como verdadero. Usando el git blame animales.py, se obtiene que quien cometió el error fue el usuario mezosky.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Para buscar los commits se usará el comando git log -p -1 [hash de commit]
#
# - El primero define la función animales, todo en el archivo main.py. Además agrega la ejecución de esta función.
# - El segundo quita la función definida en el main.py y la agrega a animales.py, separando el proyecto en modulos. Aquí se encuentra la rama main.
# - El tercer commit se refiere al que arregla los if cambiandolos por elif en el archivo main.py en la rama origin/fix-ifs.
#
# Algunas diferencias son: los commits tienen 3 autores distintos, el primer commit se hizo en la rama principal cuando no habían más ramas, el segundo se aplicó a la rama principal, pero también se usa en las ramas origin/new_features, origin/main y origin/HEAD, mientras que el tercero solo está aplicado en la rama origin/fix-ifs, aún sin haber separado el proyecto en modulos.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Se utiliza el siguiente comando para el merge: git merge origin/fix-ifs main.
# Al hacer el merge da el siguiente error:
#
# Auto-merging main.py
# CONFLICT (content): Merge conflict in main.py
# Automatic merge failed; fix conflicts and then commit the result.
#
# En este caso, esto ocurre ya que ambas ramas tienen cambios sobre el main.py. Básicamente ocurrió una colisión.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# A continuación se detalla el procedimiento:
# 1. Desde main se creó una rama nueva llamada origin/fix-fix-ifs usando git branch origin/fix-fix-ifs.
# 2. Cambié a rama nueva usando git checkout origin/fix-fix-ifs.
# 3. Luego se abrió archivo animales.py y se hicieron las siguientes modificaciones:
# - **En la novena y onceava línea se cambiaron los if por elif**
# 4. Luego se utilizó git add animales.py y git commit -m "ifs arreglados en animales.py"
# 5. Finalmente se usó el git merge origin/fix-fix-ifs main
#
# El script animales.py resultante es el que sigue:
# ```python
# def animales(input):
#
#     '''
#     Como hace el animalito?
#     '''
#
#     if input.lower() == 'gato':
#         print('miau')
#     elif input.lower() == 'perro':
#         print('guau')
#     elif input.lower() == 'fox':
#         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#     else:
#         raise ValueError('animal no reconocido :(')
# ```

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
